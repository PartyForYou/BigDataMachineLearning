# %% [markdown]
# # 2장

# %% [markdown]
# ![KakaoTalk_20230315_194140598.jpg](attachment:KakaoTalk_20230315_194140598.jpg)

# %% [markdown]
# - tab : 입력 중에 tab을 클릭하면, 해당하는 함수들이 list됩니다.
# - shift + tab : shift_tab을 입력하면 해당 함수의 설명을 볼 수 있습니다. 잘 사용하지 않는 함수는 파라미터들이 잘 기억나지ㅣ 않는데, 이럴 때 유용하게 쓸 수 있는 단축키입니다.
# - Esc + h : 주피터 노트북 단축키를 확읺할 수 있는 단축키
# - 명령어?(shift+enter) : 명령어 파라미터 확인

# %% [markdown]
# # HTML과 같은 효과
# # 파이썬 분석 보고서
# ## 파이썬 분석 보고서
# ### 파이썬 분석 보고서
